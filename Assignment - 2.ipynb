# %%
import pandas as pd

# %%
path=r"C:\Users\Arjun\Desktop\Data Analyst Assignment (1).xlsx"
sheet="Assignment-2"

# %%
df=pd.read_excel(path,sheet_name=sheet)
df.head()
# Out:
#     SKU  2019-08-01 00:00:00  2019-08-02 00:00:00  2019-08-03 00:00:00  \
# 0  2527                 1551                 1613                 1613
# 1  3042                 2240                 2330                 2423
# 2  3086                  891                  909                  936
# 3  3155                 1628                 1628                 1563
# 4  3166                  369                  354                  343
#
#    2019-08-04 00:00:00  2019-08-05 00:00:00  2019-08-06 00:00:00  \
# 0                 1532                 1517                 1441
# 1                 2350                 2374                 2398
# 2                  889                  880                  906
# 3                 1532                 1563                 1563
# 4                  340                  330                  337
#
#    2019-08-07 00:00:00  2019-08-08 00:00:00  2019-08-09 00:00:00  ...  \
# 0                 1383                 1424                 1381  ...
# ...

# %%
df.dtypes
# Out:
# SKU                    object
# 2019-08-01 00:00:00     int64
# 2019-08-02 00:00:00     int64
# 2019-08-03 00:00:00     int64
# 2019-08-04 00:00:00     int64
#                         ...
# 2020-07-27 00:00:00     int64
# 2020-07-28 00:00:00     int64
# 2020-07-29 00:00:00     int64
# 2020-07-30 00:00:00     int64
# 2020-07-31 00:00:00     int64
# Length: 367, dtype: object

# %%
df.shape
# Out:
# (247, 367)

# %%
df.columns = list(map(str, df.columns))

# %%
all(isinstance(column, str) for column in df.columns)
# Out:
# True

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.set_index("SKU",inplace=True)
df.head()
# Out:
#       2019-08-01 00:00:00  2019-08-02 00:00:00  2019-08-03 00:00:00  \
# SKU
# 2527                 1551                 1613                 1613
# 3042                 2240                 2330                 2423
# 3086                  891                  909                  936
# 3155                 1628                 1628                 1563
# 3166                  369                  354                  343
#
#       2019-08-04 00:00:00  2019-08-05 00:00:00  2019-08-06 00:00:00  \
# SKU
# 2527                 1532                 1517                 1441
# 3042                 2350                 2374                 2398
# 3086                  889                  880                  906
# 3155                 1532                 1563                 1563
# 3166                  340                  330                  337
#
#       2019-08-07 00:00:00  2019-08-08 00:00:00  2019-08-09 00:00:00  \
# SKU
# ...

# %%
df_test=df.transpose()
df_test
# Out:
# SKU                  2527  3042  3086  3155  3166  8272  9311  13159  13160  \
# 2019-08-01 00:00:00  1551  2240   891  1628   369  1034   597     57     49
# 2019-08-02 00:00:00  1613  2330   909  1628   354  1024   585     56     48
# 2019-08-03 00:00:00  1613  2423   936  1563   343  1055   608     57     48
# 2019-08-04 00:00:00  1532  2350   889  1532   340  1055   578     60     48
# 2019-08-05 00:00:00  1517  2374   880  1563   330  1055   566     58     46
# ...                   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2020-07-27 00:00:00  1926  6606   772  2030   319   690   215     34     35
# 2020-07-28 00:00:00  1926  6804   811  2050   329   669   224     34     33
# 2020-07-29 00:00:00  1849  6872   803  2132   336   649   228     33     34
# 2020-07-30 00:00:00  1904  6872   763  2111   349   649   228     32     32
# 2020-07-31 00:00:00  1828  7078   763  2027   352   630   228     31     33
#
# ...

# %%
df_test["Dates"]=df_test.index
df_test.head()
# Out:
# SKU                  2527  3042  3086  3155  3166  8272  9311  13159  13160  \
# 2019-08-01 00:00:00  1551  2240   891  1628   369  1034   597     57     49
# 2019-08-02 00:00:00  1613  2330   909  1628   354  1024   585     56     48
# 2019-08-03 00:00:00  1613  2423   936  1563   343  1055   608     57     48
# 2019-08-04 00:00:00  1532  2350   889  1532   340  1055   578     60     48
# 2019-08-05 00:00:00  1517  2374   880  1563   330  1055   566     58     46
#
# SKU                  14011  ...  PPAM05156  PPAM06156  PPAM07156  PPAM08156  \
# 2019-08-01 00:00:00      6  ...         28         15         79         93
# 2019-08-02 00:00:00      6  ...         27         15         79         93
# 2019-08-03 00:00:00      6  ...         28         15         75         89
# 2019-08-04 00:00:00      6  ...         27         15         77         85
# 2019-08-05 00:00:00      6  ...         28         15         80         88
#
# ...

# %%
df_test['month'] = pd.DatetimeIndex(df_test['Dates']).month
df_test.head()
# Out:
# SKU                  2527  3042  3086  3155  3166  8272  9311  13159  13160  \
# 2019-08-01 00:00:00  1551  2240   891  1628   369  1034   597     57     49
# 2019-08-02 00:00:00  1613  2330   909  1628   354  1024   585     56     48
# 2019-08-03 00:00:00  1613  2423   936  1563   343  1055   608     57     48
# 2019-08-04 00:00:00  1532  2350   889  1532   340  1055   578     60     48
# 2019-08-05 00:00:00  1517  2374   880  1563   330  1055   566     58     46
#
# SKU                  14011  ...  PPAM06156  PPAM07156  PPAM08156  PPAM11156  \
# 2019-08-01 00:00:00      6  ...         15         79         93          2
# 2019-08-02 00:00:00      6  ...         15         79         93          2
# 2019-08-03 00:00:00      6  ...         15         75         89          2
# 2019-08-04 00:00:00      6  ...         15         77         85          2
# 2019-08-05 00:00:00      6  ...         15         80         88          2
#
# ...

# %%
sku=df.index

# %%
sku
# Out:
# Index([       2527,        3042,        3086,        3155,        3166,
#               8272,        9311,       13159,       13160,       14011,
#        ...
#        'PPAM05126', 'PPAM05156', 'PPAM06156', 'PPAM07156', 'PPAM08156',
#        'PPAM11156', 'PSTM01257', 'PSTM01457',  'WIM5011B',  'WIM51234'],
#       dtype='object', name='SKU', length=247)

# %%
df_test
# Out:
# SKU                  2527  3042  3086  3155  3166  8272  9311  13159  13160  \
# 2019-08-01 00:00:00  1551  2240   891  1628   369  1034   597     57     49
# 2019-08-02 00:00:00  1613  2330   909  1628   354  1024   585     56     48
# 2019-08-03 00:00:00  1613  2423   936  1563   343  1055   608     57     48
# 2019-08-04 00:00:00  1532  2350   889  1532   340  1055   578     60     48
# 2019-08-05 00:00:00  1517  2374   880  1563   330  1055   566     58     46
# ...                   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2020-07-27 00:00:00  1926  6606   772  2030   319   690   215     34     35
# 2020-07-28 00:00:00  1926  6804   811  2050   329   669   224     34     33
# 2020-07-29 00:00:00  1849  6872   803  2132   336   649   228     33     34
# 2020-07-30 00:00:00  1904  6872   763  2111   349   649   228     32     32
# 2020-07-31 00:00:00  1828  7078   763  2027   352   630   228     31     33
#
# ...

# %%
df_grp=df_test.groupby(["month"]).sum()

# %%
df_grp
# Out:
# SKU     2527    3042   3086   3155   3166   8272   9311  13159  13160  14011  \
# month
# 1      21853   79546  35670  75218  13990  16265   8532   2297   1248    186
# 2      23170   78095  32029  61235  10517  14922   7193   2001   1154    174
# 3      30956   92606  30827  72241   9587  18244   8971   1967    949    186
# 4      38202  120947  25062  67543  12110  24042   9115   1800    845    180
# 5      44347  135342  22231  57518   9838  33069  10741   1447   1062    186
# 6      49341  157482  24184  53480   9076  22895   8341   1087   1261    180
# 7      55826  196062  26153  54253  10182  20594   6834   1150   1168    186
# 8      41702   69451  27412  46443  10720  31559  19045   1822   1485    186
# 9      36880   62415  31687  41922  10306  35877  17797   1990   1753    180
# 10     30582   71082  33122  45421  11966  35109  14797   1857   2045    186
# 11     21916   83246  28937  55371  13094  35407  11495   1853   1445    180
# ...

# %%
df_grp["Total"]=df_grp.sum(axis=1)

# %% [markdown]
# ## Monthly Sales By SKU

# %%
df_grp
# Out:
# SKU     2527    3042   3086   3155   3166   8272   9311  13159  13160  14011  \
# month
# 1      21853   79546  35670  75218  13990  16265   8532   2297   1248    186
# 2      23170   78095  32029  61235  10517  14922   7193   2001   1154    174
# 3      30956   92606  30827  72241   9587  18244   8971   1967    949    186
# 4      38202  120947  25062  67543  12110  24042   9115   1800    845    180
# 5      44347  135342  22231  57518   9838  33069  10741   1447   1062    186
# 6      49341  157482  24184  53480   9076  22895   8341   1087   1261    180
# 7      55826  196062  26153  54253  10182  20594   6834   1150   1168    186
# 8      41702   69451  27412  46443  10720  31559  19045   1822   1485    186
# 9      36880   62415  31687  41922  10306  35877  17797   1990   1753    180
# 10     30582   71082  33122  45421  11966  35109  14797   1857   2045    186
# 11     21916   83246  28937  55371  13094  35407  11495   1853   1445    180
# ...

# %%
df_grp[["Total"]]
# Out:
# SKU       Total
# month
# 1      19170099
# 2      17973457
# 3      20234570
# 4      19103472
# 5      18555947
# 6      18303531
# 7      18795771
# 8      16590204
# 9      17309331
# 10     18300108
# 11     17954015
# 12     19536270

# %% [markdown]
# ## Top 3 months are March, December and January orderly

# %%
Q1 = df_grp.quantile(0.25)
Q3 = df_grp.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# SKU
# 2527           18717.75
# 3042           48204.00
# 3086            6422.00
# 3155           16996.75
# 3166            2260.00
#                 ...
# PSTM01257         71.00
# PSTM01457         40.75
# WIM5011B        1010.25
# WIM51234           2.00
# Total        1151532.25
# Length: 248, dtype: float64

# %%
print(df_grp < (Q1 - 1.5 * IQR)) |(df_grp > (Q3 + 1.5 * IQR))
